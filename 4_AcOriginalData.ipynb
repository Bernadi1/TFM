# %%
import pandas as pd
import numpy as np
import os

from sklearn import preprocessing
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import randint as sp_randint
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.metrics import balanced_accuracy_score

from sklearn.model_selection import KFold
from sklearn.metrics import recall_score

# %% [markdown]
# ---
# ---
# Leemos datos

# %%
ruta = '/content/drive/MyDrive/TFM/TFM/Processed_Data/DataSetAdenocarcinomaSinOutliers.csv'
dataset = pd.read_csv(ruta, sep="\t")

# %%
# Normalizamos las características dentro del rango [0,1]
min_max_scaler = preprocessing.MinMaxScaler()

# Quitamos la columna de ID
columnas = dataset.columns.tolist()
columnas.remove(columnas[0])

features_norm = min_max_scaler.fit_transform(dataset[columnas])

dataset_norm = pd.DataFrame(features_norm, columns=columnas)

X = dataset_norm.drop(columns=['Adenocarcinoma'])  # Variables predictoras
y = dataset_norm['Adenocarcinoma']  # Variable objetivo

# %%
#definimos funcion para mostrar los resultados
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix

LABELS = ["Healthy","Disease"]

def mostrar_resultados(y_test, pred_y):
    conf_matrix = confusion_matrix(y_test, pred_y)
    plt.figure(figsize=(9, 9))
    sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
    plt.title("Confusion matrix")
    plt.ylabel('True class')
    plt.xlabel('Predicted class')
    plt.show()

def medidas(cm):
  VP = cm[1][1]
  FP = cm[0][1]
  VN = cm[0][0]
  FN = cm[1][0]
  print("Precision:",round(VP/(VP+FP)*100,2))
  print("Especificidad:",round(VN/(VN+FP)*100,2))
  print("Exactitud:",round((VP+VN)/(VP+VN+FP+FN)*100,2))
  print("Sensibilidad:",round(VP/(VP+FN)*100,2))
  print("Error tipo I:",round(FP/(VN+FP)*100,2))
  print("Error tipo II:",round(FN/(VP+FN)*100,2))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# %%
def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

# %% [markdown]
# # Regresión logística

# %%
# Inicializar y entrenar el modelo de regresión logística
model = LogisticRegression()
model.fit(X_train, y_train)

# Predecir en el conjunto de prueba
y_pred = model.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 86.55
# Especificidad: 88.64
# Exactitud: 89.01
# Sensibilidad: 89.46
# Error tipo I: 11.36
# Error tipo II: 10.54

# %% [markdown]
# ## Random Search

# %%
param_dist = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],  # Parámetro de regularización
    'penalty': ['l2', None],  # Tipo de penalización
    'solver': ['lbfgs', 'newton-cg', 'newton-cholesky', 'sag'],  # Algoritmo de optimización
    'class_weight': ['balanced', None] # Parámetro para ajustar los pesos de las clases
}

# %%
# Inicializar y entrenar el modelo de regresión logística
model = LogisticRegression()

# Realizar la búsqueda aleatoria de hiperparámetros
random_search = RandomizedSearchCV(estimator=model, param_distributions=param_dist, scoring=make_scorer(balanced_accuracy_score),
                                   n_iter=100, cv=5, random_state=42, n_jobs=-1)
random_search.fit(X_train, y_train)

# Obtener el mejor modelo
best_model = random_search.best_estimator_

# Predecir en el conjunto de prueba
y_pred = best_model.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:305: UserWarning: The total space of parameters 96 is smaller than n_iter=100. Running 96 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Precision: 85.25
# Especificidad: 86.81
# Exactitud: 89.72
# Sensibilidad: 93.27
# Error tipo I: 13.19
# Error tipo II: 6.73

# %%
report(random_search.cv_results_, n_top = 3)
# Out:
# Model with rank: 1
# Mean validation score: 0.885 (std: 0.006)
# Parameters: {'solver': 'lbfgs', 'penalty': 'l2', 'class_weight': 'balanced', 'C': 1}
#
# Model with rank: 1
# Mean validation score: 0.885 (std: 0.006)
# Parameters: {'solver': 'newton-cg', 'penalty': 'l2', 'class_weight': 'balanced', 'C': 1}
#
# Model with rank: 1
# Mean validation score: 0.885 (std: 0.006)
# Parameters: {'solver': 'newton-cholesky', 'penalty': 'l2', 'class_weight': 'balanced', 'C': 1}

# %% [markdown]
# # Modelo KNN

# %%
# Inicializar el clasificador k-NN
knn = KNeighborsClassifier(n_neighbors=10, weights = 'distance')

# Entrenar el modelo
knn.fit(X_train, y_train)

# Realizar predicciones en el conjunto de prueba
y_pred = knn.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 84.72
# Especificidad: 87.91
# Exactitud: 85.28
# Sensibilidad: 82.06
# Error tipo I: 12.09
# Error tipo II: 17.94

# %% [markdown]
# ## Random Search

# %%
param_dist = {
    'n_neighbors': sp_randint(1, 20),  # Número de vecinos
    'weights': ['uniform', 'distance'],  # Método de asignación de pesos
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],  # Algoritmo para calcular los vecinos
    'leaf_size': sp_randint(10, 50),  # Tamaño de la hoja para algoritmos de árbol
    'p': [1, 2]  # Parámetro de potencia para la métrica Minkowski
}

# %%
# Inicializar el clasificador k-NN
knn = KNeighborsClassifier()

# Realizar la búsqueda aleatoria de hiperparámetros
random_search = RandomizedSearchCV(estimator=knn, param_distributions=param_dist, scoring=make_scorer(balanced_accuracy_score),
                                   n_iter=100, cv=5, random_state=42, n_jobs=-1)
random_search.fit(X_train, y_train)

# Obtener el mejor modelo
best_model = random_search.best_estimator_

# Realizar predicciones en el conjunto de prueba
y_pred = best_model.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 85.27
# Especificidad: 87.91
# Exactitud: 86.9
# Sensibilidad: 85.65
# Error tipo I: 12.09
# Error tipo II: 14.35

# %% [markdown]
# # Modelo Árbol de Decisión

# %%
# Inicializar el clasificador de árbol de decisión
dt_classifier = DecisionTreeClassifier(max_depth=10, random_state=42)

# Entrenar el modelo
dt_classifier.fit(X_train, y_train)

# Realizar predicciones en el conjunto de prueba
y_pred = dt_classifier.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 83.89
# Especificidad: 86.63
# Exactitud: 85.99
# Sensibilidad: 85.2
# Error tipo I: 13.37
# Error tipo II: 14.8

# %% [markdown]
# ## Random Search

# %%
param_dist = {
    'criterion': ['gini', 'entropy'],  # Criterio de calidad de la partición
    'splitter': ['best', 'random'],  # Estrategia para elegir la división en cada nodo
    'max_depth': [None] + list(sp_randint(1, 20).rvs(10)),  # Profundidad máxima del árbol
    'min_samples_split': sp_randint(2, 20),  # Número mínimo de muestras requeridas para dividir un nodo interno
    'min_samples_leaf': sp_randint(1, 20),  # Número mínimo de muestras requeridas para ser una hoja
    'max_features': ['auto', 'sqrt', 'log2', None],  # Número máximo de características a considerar en cada división
    'ccp_alpha': np.linspace(0.0, 0.5, 10)  # Parámetro de complejidad de coste mínimo
}

# %%
# Inicializar el clasificador de árbol de decisión
dt_classifier = DecisionTreeClassifier()

# Realizar la búsqueda aleatoria de hiperparámetros
random_search = RandomizedSearchCV(estimator=dt_classifier, param_distributions=param_dist, scoring=make_scorer(balanced_accuracy_score),
                                   n_iter=100, cv=5, random_state=42, n_jobs=-1)
random_search.fit(X_train, y_train)

# Obtener el mejor modelo
best_model = random_search.best_estimator_

# Realizar predicciones en el conjunto de prueba
y_pred = best_model.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 83.22
# Especificidad: 86.26
# Exactitud: 84.98
# Sensibilidad: 83.41
# Error tipo I: 13.74
# Error tipo II: 16.59

# %% [markdown]
# # Modelo Bosque Aleatorio

# %%
# Inicializar el clasificador de bosque aleatorio
rf_regressor  = RandomForestClassifier(max_depth=10, random_state=42)

# Entrenar el modelo
rf_regressor.fit(X_train, y_train)

# Realizar predicciones en el conjunto de prueba
y_pred = rf_regressor .predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 87.21
# Especificidad: 89.01
# Exactitud: 90.22
# Sensibilidad: 91.7
# Error tipo I: 10.99
# Error tipo II: 8.3

# %% [markdown]
# ## Random Search

# %%
param_dist = {"n_estimators": [8, 16, 32], # Número de árboles en el bosque aleatorio
              "max_features": ['auto', 'sqrt'], # Número de características a considerar en cada división
              "max_depth": [12, 8, 4], # Número máximo de niveles en el árbol
              "min_samples_split": sp_randint(2, 10), # Número mínimo de muestras requeridas para dividir un nodo
              "min_samples_leaf": sp_randint(1, 10), # Número mínimo de muestras requeridas en cada nodo hoja
              "bootstrap": [True, False], # Método de selección de muestras para entrenar cada árbol
              "criterion": ['log_loss', 'entropy', 'gini']} # Criterio de evaluación de la calidad de una división

# %%
classifier =  RandomForestClassifier()

# Realizar la búsqueda aleatoria de hiperparámetros
rnd_class = RandomizedSearchCV(estimator = classifier, param_distributions = param_dist,
                               n_iter = 100, cv = 5, random_state=42, n_jobs = -1,
                               scoring=make_scorer(balanced_accuracy_score))
rnd_class.fit(X_train, y_train)

# Inicializar el clasificador de bosque de árboles de decisión
classifier =  rnd_class.best_estimator_

# Realizar predicciones en el conjunto de prueba
y_pred = classifier.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 86.97
# Especificidad: 88.64
# Exactitud: 90.52
# Sensibilidad: 92.83
# Error tipo I: 11.36
# Error tipo II: 7.17

# %% [markdown]
# # Red neuronal

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Activation, Flatten
from tensorflow.keras.utils import plot_model
import keras.backend as K

# %%
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1 - y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

# %%
# Define la arquitectura de la red neuronal
model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),  # Capa oculta con activación ReLU
    Dropout(0.5),  # Dropout para regularización
    Dense(8, activation='relu'),  # capa oculta
    Dense(1, activation='relu')  # Capa de salida
])

# Compila el modelo
model.compile(optimizer='adam', loss='binary_crossentropy', metrics = ['accuracy', specificity])

# Entrena el modelo
model.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 2s 7ms/step - loss: 0.7378 - accuracy: 0.6352 - specificity: 0.9164 - val_loss: 0.4449 - val_accuracy: 0.7406 - val_specificity: 0.9215
# Epoch 2/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.4970 - accuracy: 0.7631 - specificity: 0.9028 - val_loss: 0.4611 - val_accuracy: 0.8350 - val_specificity: 0.9053
# Epoch 3/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4796 - accuracy: 0.7376 - specificity: 0.9316 - val_loss: 0.4178 - val_accuracy: 0.7821 - val_specificity: 0.9394
# Epoch 4/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4021 - accuracy: 0.8018 - specificity: 0.9141 - val_loss: 0.4581 - val_accuracy: 0.8363 - val_specificity: 0.9218
# Epoch 5/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3773 - accuracy: 0.8296 - specificity: 0.9053 - val_loss: 0.4555 - val_accuracy: 0.8463 - val_specificity: 0.9273
# Epoch 6/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3446 - accuracy: 0.8522 - specificity: 0.9109 - val_loss: 0.4553 - val_accuracy: 0.8665 - val_specificity: 0.9142
# Epoch 7/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3349 - accuracy: 0.8645 - specificity: 0.9066 - val_loss: 0.4531 - val_accuracy: 0.8615 - val_specificity: 0.9166
# Epoch 8/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2970 - accuracy: 0.8781 - specificity: 0.9191 - val_loss: 0.4329 - val_accuracy: 0.8627 - val_specificity: 0.9147
# Epoch 9/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2790 - accuracy: 0.8913 - specificity: 0.9284 - val_loss: 0.5196 - val_accuracy: 0.8388 - val_specificity: 0.9320
# Epoch 10/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2747 - accuracy: 0.8885 - specificity: 0.9260 - val_loss: 0.4885 - val_accuracy: 0.8665 - val_specificity: 0.8992
# Epoch 11/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2587 - accuracy: 0.9049 - specificity: 0.9278 - val_loss: 0.4620 - val_accuracy: 0.8652 - val_specificity: 0.8890
# Epoch 12/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2198 - accuracy: 0.9231 - specificity: 0.9425 - val_loss: 0.5154 - val_accuracy: 0.8766 - val_specificity: 0.8823
# Epoch 13/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2093 - accuracy: 0.9175 - specificity: 0.9415 - val_loss: 0.5119 - val_accuracy: 0.8539 - val_specificity: 0.9194
# Epoch 14/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2010 - accuracy: 0.9247 - specificity: 0.9390 - val_loss: 0.5956 - val_accuracy: 0.8577 - val_specificity: 0.9072
# Epoch 15/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1989 - accuracy: 0.9313 - specificity: 0.9537 - val_loss: 0.5895 - val_accuracy: 0.8678 - val_specificity: 0.8865
# Epoch 16/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.1990 - accuracy: 0.9253 - specificity: 0.9471 - val_loss: 0.6064 - val_accuracy: 0.8766 - val_specificity: 0.8815
# Epoch 17/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1860 - accuracy: 0.9367 - specificity: 0.9459 - val_loss: 0.5767 - val_accuracy: 0.8262 - val_specificity: 0.9367
# Epoch 18/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2998 - accuracy: 0.8595 - specificity: 0.9698 - val_loss: 0.5078 - val_accuracy: 0.8363 - val_specificity: 0.9366
# Epoch 19/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1948 - accuracy: 0.9190 - specificity: 0.9541 - val_loss: 0.6392 - val_accuracy: 0.8627 - val_specificity: 0.9005
# Epoch 20/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1947 - accuracy: 0.9275 - specificity: 0.9536 - val_loss: 0.5842 - val_accuracy: 0.8539 - val_specificity: 0.9006
# Epoch 21/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1762 - accuracy: 0.9370 - specificity: 0.9514 - val_loss: 0.6445 - val_accuracy: 0.8678 - val_specificity: 0.9099
# Epoch 22/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1847 - accuracy: 0.9338 - specificity: 0.9484 - val_loss: 0.6354 - val_accuracy: 0.8690 - val_specificity: 0.9031
# Epoch 23/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1460 - accuracy: 0.9483 - specificity: 0.9601 - val_loss: 0.7347 - val_accuracy: 0.8652 - val_specificity: 0.9062
# Epoch 24/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1550 - accuracy: 0.9499 - specificity: 0.9606 - val_loss: 0.6333 - val_accuracy: 0.8652 - val_specificity: 0.8986
# Epoch 25/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.1488 - accuracy: 0.9578 - specificity: 0.9607 - val_loss: 0.7614 - val_accuracy: 0.8627 - val_specificity: 0.8926
# Epoch 26/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.1289 - accuracy: 0.9622 - specificity: 0.9601 - val_loss: 0.8098 - val_accuracy: 0.8627 - val_specificity: 0.9078
# Epoch 27/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1243 - accuracy: 0.9575 - specificity: 0.9618 - val_loss: 0.7576 - val_accuracy: 0.8678 - val_specificity: 0.8950
# Epoch 28/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1239 - accuracy: 0.9603 - specificity: 0.9629 - val_loss: 1.0078 - val_accuracy: 0.8489 - val_specificity: 0.9324
# Epoch 29/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.1425 - accuracy: 0.9527 - specificity: 0.9571 - val_loss: 0.6800 - val_accuracy: 0.8388 - val_specificity: 0.9113
# Epoch 30/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.1211 - accuracy: 0.9581 - specificity: 0.9570 - val_loss: 0.7795 - val_accuracy: 0.8476 - val_specificity: 0.8996
# Epoch 31/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.1055 - accuracy: 0.9669 - specificity: 0.9654 - val_loss: 0.8262 - val_accuracy: 0.8703 - val_specificity: 0.8936
# Epoch 32/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.1147 - accuracy: 0.9666 - specificity: 0.9709 - val_loss: 0.8769 - val_accuracy: 0.8690 - val_specificity: 0.9040
# Epoch 33/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0970 - accuracy: 0.9707 - specificity: 0.9664 - val_loss: 0.8868 - val_accuracy: 0.8741 - val_specificity: 0.8933
# Epoch 34/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0879 - accuracy: 0.9739 - specificity: 0.9666 - val_loss: 0.9809 - val_accuracy: 0.8577 - val_specificity: 0.9078
# Epoch 35/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0786 - accuracy: 0.9751 - specificity: 0.9733 - val_loss: 0.8686 - val_accuracy: 0.8766 - val_specificity: 0.8910
# Epoch 36/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0844 - accuracy: 0.9735 - specificity: 0.9654 - val_loss: 1.2198 - val_accuracy: 0.8401 - val_specificity: 0.9125
# Epoch 37/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0742 - accuracy: 0.9773 - specificity: 0.9730 - val_loss: 1.0124 - val_accuracy: 0.8564 - val_specificity: 0.9031
# Epoch 38/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0827 - accuracy: 0.9739 - specificity: 0.9724 - val_loss: 0.9880 - val_accuracy: 0.8690 - val_specificity: 0.8926
# Epoch 39/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0886 - accuracy: 0.9767 - specificity: 0.9709 - val_loss: 1.1180 - val_accuracy: 0.8577 - val_specificity: 0.9031
# Epoch 40/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0680 - accuracy: 0.9805 - specificity: 0.9719 - val_loss: 1.1231 - val_accuracy: 0.8577 - val_specificity: 0.9010
# Epoch 41/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0637 - accuracy: 0.9827 - specificity: 0.9669 - val_loss: 1.0275 - val_accuracy: 0.8615 - val_specificity: 0.9009
# Epoch 42/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0740 - accuracy: 0.9805 - specificity: 0.9714 - val_loss: 1.2480 - val_accuracy: 0.8350 - val_specificity: 0.9208
# Epoch 43/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0781 - accuracy: 0.9792 - specificity: 0.9772 - val_loss: 1.0780 - val_accuracy: 0.8602 - val_specificity: 0.8968
# Epoch 44/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0925 - accuracy: 0.9761 - specificity: 0.9746 - val_loss: 0.9915 - val_accuracy: 0.8627 - val_specificity: 0.9031
# Epoch 45/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0677 - accuracy: 0.9830 - specificity: 0.9767 - val_loss: 1.1462 - val_accuracy: 0.8589 - val_specificity: 0.9052
# Epoch 46/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0731 - accuracy: 0.9795 - specificity: 0.9706 - val_loss: 1.1719 - val_accuracy: 0.8615 - val_specificity: 0.9048
# Epoch 47/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0747 - accuracy: 0.9836 - specificity: 0.9766 - val_loss: 1.0766 - val_accuracy: 0.8678 - val_specificity: 0.8895
# Epoch 48/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0529 - accuracy: 0.9836 - specificity: 0.9755 - val_loss: 1.2140 - val_accuracy: 0.8564 - val_specificity: 0.9041
# Epoch 49/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0884 - accuracy: 0.9786 - specificity: 0.9834 - val_loss: 1.1313 - val_accuracy: 0.8577 - val_specificity: 0.9031
# Epoch 50/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0614 - accuracy: 0.9855 - specificity: 0.9761 - val_loss: 1.1736 - val_accuracy: 0.8552 - val_specificity: 0.9006

# %%
# Evaluar el modelo en el conjunto de prueba (si tienes uno)
# Predecir en el conjunto de prueba
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# 31/31 [==============================] - 0s 2ms/step
# Precision: 86.68
# Especificidad: 89.19
# Exactitud: 87.8
# Sensibilidad: 86.1
# Error tipo I: 10.81
# Error tipo II: 13.9
