# %%
import pandas as pd
import numpy as np
import os

from sklearn import preprocessing
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import randint as sp_randint
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer
from sklearn.metrics import balanced_accuracy_score


from sklearn.model_selection import KFold
from sklearn.metrics import recall_score

# %% [markdown]
# ---
# ---
# Leemos datos

# %%
ruta = '/content/drive/MyDrive/TFM/TFM/Processed_Data/DataSetSinOutliers.csv'
dataset = pd.read_csv(ruta, sep="\t")

# %% [markdown]
# # Elección de columnas mediante correlación

# %%
# Normalizamos las características dentro del rango [0,1]
min_max_scaler = preprocessing.MinMaxScaler()

# Quitamos la columna de ID
columnas = dataset.columns.tolist()
columnas.remove(columnas[0])

features_norm = min_max_scaler.fit_transform(dataset[columnas])

dataset_norm = pd.DataFrame(features_norm, columns=columnas)


correlation_matrix = dataset_norm.corr()
relevant_columns = correlation_matrix[abs(correlation_matrix['Health_state_disease']) > 0.05].index
dataset_norm = dataset_norm[relevant_columns]

X = dataset_norm.drop(columns=['Health_state_disease'])  # Variables predictoras
y = dataset_norm['Health_state_disease']  # Variable objetivo

# %%
#definimos funcion para mostrar los resultados
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix

LABELS = ["Healthy","Disease"]

def mostrar_resultados(y_test, pred_y):
    conf_matrix = confusion_matrix(y_test, pred_y)
    plt.figure(figsize=(9, 9))
    sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
    plt.title("Confusion matrix")
    plt.ylabel('True class')
    plt.xlabel('Predicted class')
    plt.show()

def medidas(cm):
  VP = cm[1][1]
  FP = cm[0][1]
  VN = cm[0][0]
  FN = cm[1][0]
  print("Precision:",round(VP/(VP+FP)*100,2))
  print("Especificidad:",round(VN/(VN+FP)*100,2))
  print("Exactitud:",round((VP+VN)/(VP+VN+FP+FN)*100,2))
  print("Sensibilidad:",round(VP/(VP+FN)*100,2))
  print("Error tipo I:",round(FP/(VN+FP)*100,2))
  print("Error tipo II:",round(FN/(VP+FN)*100,2))

# %% [markdown]
# # Random Over Sampler

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# Creamos con RandomOverSampler muestras de la clase minoritaria para contrarrestar el desbalanceo de clases
os =  RandomOverSampler(sampling_strategy=0.5)
X_train_res, y_train_res = os.fit_resample(X_train, y_train)

# %%
def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

# %% [markdown]
# # Regresión logística

# %%
# Inicializar y entrenar el modelo de regresión logística
model = LogisticRegression()
model.fit(X_train_res, y_train_res)

# Predecir en el conjunto de prueba
y_pred = model.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 99.45
# Especificidad: 92.06
# Exactitud: 96.37
# Sensibilidad: 96.66
# Error tipo I: 7.94
# Error tipo II: 3.34

# %% [markdown]
# ## Random Search

# %%
param_dist = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],  # Parámetro de regularización
    'penalty': ['l2', None],  # Tipo de penalización
    'solver': ['lbfgs', 'newton-cg', 'newton-cholesky', 'sag'],  # Algoritmo de optimización
    'class_weight': ['balanced', None] # Parámetro para ajustar los pesos de las clases
}

# %%
# Inicializar y entrenar el modelo de regresión logística
model = LogisticRegression()

# Realizar la búsqueda aleatoria de hiperparámetros
random_search = RandomizedSearchCV(estimator=model, param_distributions=param_dist, scoring=make_scorer(balanced_accuracy_score),
                                   n_iter=100, cv=5, random_state=42, n_jobs=-1)
random_search.fit(X_train_res, y_train_res)

# Obtener el mejor modelo
best_model = random_search.best_estimator_

# Predecir en el conjunto de prueba
y_pred = best_model.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:305: UserWarning: The total space of parameters 96 is smaller than n_iter=100. Running 96 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Precision: 98.27
# Especificidad: 74.6
# Exactitud: 96.57
# Sensibilidad: 98.06
# Error tipo I: 25.4
# Error tipo II: 1.94

# %%
report(random_search.cv_results_, n_top = 3)
# Out:
# Model with rank: 1
# Mean validation score: 0.985 (std: 0.002)
# Parameters: {'solver': 'lbfgs', 'penalty': None, 'class_weight': None, 'C': 0.001}
#
# Model with rank: 1
# Mean validation score: 0.985 (std: 0.002)
# Parameters: {'solver': 'lbfgs', 'penalty': None, 'class_weight': None, 'C': 0.01}
#
# Model with rank: 1
# Mean validation score: 0.985 (std: 0.002)
# Parameters: {'solver': 'lbfgs', 'penalty': None, 'class_weight': None, 'C': 0.1}
#
# Model with rank: 1
# Mean validation score: 0.985 (std: 0.002)
# Parameters: {'solver': 'lbfgs', 'penalty': None, 'class_weight': None, 'C': 1}
#
# Model with rank: 1
# Mean validation score: 0.985 (std: 0.002)
# Parameters: {'solver': 'lbfgs', 'penalty': None, 'class_weight': None, 'C': 10}
#
# Model with rank: 1
# Mean validation score: 0.985 (std: 0.002)
# Parameters: {'solver': 'lbfgs', 'penalty': None, 'class_weight': None, 'C': 100}

# %% [markdown]
# # Modelo KNN

# %%
# Inicializar el clasificador k-NN
knn = KNeighborsClassifier(n_neighbors=10, weights = 'distance')

# Entrenar el modelo
knn.fit(X_train_res, y_train_res)

# Realizar predicciones en el conjunto de prueba
y_pred = knn.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 99.65
# Especificidad: 95.24
# Exactitud: 91.13
# Sensibilidad: 90.85
# Error tipo I: 4.76
# Error tipo II: 9.15

# %% [markdown]
# ## Random Search

# %%
param_dist = {
    'n_neighbors': sp_randint(1, 20),  # Número de vecinos
    'weights': ['uniform', 'distance'],  # Método de asignación de pesos
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],  # Algoritmo para calcular los vecinos
    'leaf_size': sp_randint(10, 50),  # Tamaño de la hoja para algoritmos de árbol
    'p': [1, 2]  # Parámetro de potencia para la métrica Minkowski
}

# %%
# Inicializar el clasificador k-NN
knn = KNeighborsClassifier()

# Realizar la búsqueda aleatoria de hiperparámetros
random_search = RandomizedSearchCV(estimator=knn, param_distributions=param_dist, scoring=make_scorer(balanced_accuracy_score),
                                   n_iter=100, cv=5, random_state=42, n_jobs=-1)
random_search.fit(X_train_res, y_train_res)

# Obtener el mejor modelo
best_model = random_search.best_estimator_

# Realizar predicciones en el conjunto de prueba
y_pred = best_model.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 99.02
# Especificidad: 85.71
# Exactitud: 96.88
# Sensibilidad: 97.63
# Error tipo I: 14.29
# Error tipo II: 2.37

# %% [markdown]
# # Modelo Árbol de Decisión

# %%
# Inicializar el clasificador de árbol de decisión
dt_classifier = DecisionTreeClassifier(max_depth=10, random_state=42)

# Entrenar el modelo
dt_classifier.fit(X_train_res, y_train_res)

# Realizar predicciones en el conjunto de prueba
y_pred = dt_classifier.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 98.32
# Especificidad: 76.19
# Exactitud: 93.45
# Sensibilidad: 94.62
# Error tipo I: 23.81
# Error tipo II: 5.38

# %% [markdown]
# ## Random Search

# %%
param_dist = {
    'criterion': ['gini', 'entropy'],  # Criterio de calidad de la partición
    'splitter': ['best', 'random'],  # Estrategia para elegir la división en cada nodo
    'max_depth': [None] + list(sp_randint(1, 20).rvs(10)),  # Profundidad máxima del árbol
    'min_samples_split': sp_randint(2, 20),  # Número mínimo de muestras requeridas para dividir un nodo interno
    'min_samples_leaf': sp_randint(1, 20),  # Número mínimo de muestras requeridas para ser una hoja
    'max_features': ['auto', 'sqrt', 'log2', None],  # Número máximo de características a considerar en cada división
    'ccp_alpha': np.linspace(0.0, 0.5, 10)  # Parámetro de complejidad de coste mínimo
}

# %%
# Inicializar el clasificador de árbol de decisión
dt_classifier = DecisionTreeClassifier()

# Realizar la búsqueda aleatoria de hiperparámetros
random_search = RandomizedSearchCV(estimator=dt_classifier, param_distributions=param_dist, scoring=make_scorer(balanced_accuracy_score),
                                   n_iter=100, cv=5, random_state=42, n_jobs=-1)
random_search.fit(X_train_res, y_train_res)

# Obtener el mejor modelo
best_model = random_search.best_estimator_

# Realizar predicciones en el conjunto de prueba
y_pred = best_model.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# Precision: 96.86
# Especificidad: 53.97
# Exactitud: 93.65
# Sensibilidad: 96.34
# Error tipo I: 46.03
# Error tipo II: 3.66

# %% [markdown]
# # Modelo Bosque Aleatorio

# %%
# Inicializar el clasificador de bosque aleatorio
rf_regressor  = RandomForestClassifier(max_depth=10, random_state=42)

# Entrenar el modelo
rf_regressor.fit(X_train_res, y_train_res)

# Realizar predicciones en el conjunto de prueba
y_pred = rf_regressor .predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 98.81
# Especificidad: 82.54
# Exactitud: 97.48
# Sensibilidad: 98.49
# Error tipo I: 17.46
# Error tipo II: 1.51

# %% [markdown]
# ## Random Search

# %%
param_dist = {"n_estimators": [8, 16, 32], # Número de árboles en el bosque aleatorio
              "max_features": ['auto', 'sqrt'], # Número de características a considerar en cada división
              "max_depth": [12, 8, 4], # Número máximo de niveles en el árbol
              "min_samples_split": sp_randint(2, 10), # Número mínimo de muestras requeridas para dividir un nodo
              "min_samples_leaf": sp_randint(1, 10), # Número mínimo de muestras requeridas en cada nodo hoja
              "bootstrap": [True, False], # Método de selección de muestras para entrenar cada árbol
              "criterion": ['log_loss', 'entropy', 'gini']} # Criterio de evaluación de la calidad de una división

# %%
classifier =  RandomForestClassifier()

# Realizar la búsqueda aleatoria de hiperparámetros
rnd_class = RandomizedSearchCV(estimator = classifier, param_distributions = param_dist,
                               n_iter = 100, cv = 5, random_state=0, n_jobs = -1,
                               scoring=make_scorer(balanced_accuracy_score))
rnd_class.fit(X_train_res, y_train_res)

# Inicializar el clasificador de bosque de árboles de decisión
classifier =  rnd_class.best_estimator_

# Entrenar el modelo
classifier.fit(X_train_res, y_train_res)

# Realizar predicciones en el conjunto de prueba
y_pred = classifier.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 97.68
# Especificidad: 65.08
# Exactitud: 97.48
# Sensibilidad: 99.68
# Error tipo I: 34.92
# Error tipo II: 0.32

# %% [markdown]
# # Red neuronal

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Activation, Flatten
from tensorflow.keras.utils import plot_model
import keras.backend as K

# %%
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1 - y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

# %%
# Define la arquitectura de la red neuronal
model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),  # Capa oculta con activación ReLU
    Dropout(0.5),  # Dropout para regularización
    Dense(8, activation='relu'),  # capa oculta
    Dense(1, activation='relu')  # Capa de salida
])

# Compila el modelo
model.compile(optimizer='adam', loss='binary_crossentropy', metrics = ['accuracy', specificity])

# Entrena el modelo
model.fit(X_train_res, y_train_res, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 138/138 [==============================] - 2s 5ms/step - loss: 1.0639 - accuracy: 0.7063 - specificity: 0.4401 - val_loss: 0.7814 - val_accuracy: 0.6922 - val_specificity: 0.6923
# Epoch 2/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.5070 - accuracy: 0.8265 - specificity: 0.6812 - val_loss: 0.5683 - val_accuracy: 0.8333 - val_specificity: 0.8327
# Epoch 3/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.3450 - accuracy: 0.8682 - specificity: 0.6992 - val_loss: 0.4715 - val_accuracy: 0.8843 - val_specificity: 0.8827
# Epoch 4/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.2840 - accuracy: 0.8971 - specificity: 0.7244 - val_loss: 0.5489 - val_accuracy: 0.8452 - val_specificity: 0.8443
# Epoch 5/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.2392 - accuracy: 0.9144 - specificity: 0.7458 - val_loss: 0.5588 - val_accuracy: 0.8470 - val_specificity: 0.8461
# Epoch 6/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.2029 - accuracy: 0.9260 - specificity: 0.8039 - val_loss: 0.6122 - val_accuracy: 0.8570 - val_specificity: 0.8579
# Epoch 7/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.2074 - accuracy: 0.9367 - specificity: 0.8433 - val_loss: 0.5800 - val_accuracy: 0.8898 - val_specificity: 0.8900
# Epoch 8/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.1920 - accuracy: 0.9442 - specificity: 0.8226 - val_loss: 0.6099 - val_accuracy: 0.8798 - val_specificity: 0.8802
# Epoch 9/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.2301 - accuracy: 0.9199 - specificity: 0.8352 - val_loss: 0.4949 - val_accuracy: 0.9180 - val_specificity: 0.9196
# Epoch 10/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.2047 - accuracy: 0.9372 - specificity: 0.8155 - val_loss: 0.5844 - val_accuracy: 0.8953 - val_specificity: 0.8934
# Epoch 11/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.1542 - accuracy: 0.9472 - specificity: 0.8622 - val_loss: 0.4701 - val_accuracy: 0.9226 - val_specificity: 0.9241
# Epoch 12/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.1505 - accuracy: 0.9533 - specificity: 0.9172 - val_loss: 0.4962 - val_accuracy: 0.9144 - val_specificity: 0.9141
# Epoch 13/50
# 138/138 [==============================] - 0s 4ms/step - loss: 0.1430 - accuracy: 0.9595 - specificity: 0.9052 - val_loss: 0.4570 - val_accuracy: 0.9162 - val_specificity: 0.9179
# Epoch 14/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.1372 - accuracy: 0.9631 - specificity: 0.8918 - val_loss: 0.6291 - val_accuracy: 0.8379 - val_specificity: 0.8371
# Epoch 15/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.1419 - accuracy: 0.9583 - specificity: 0.8869 - val_loss: 0.3845 - val_accuracy: 0.9281 - val_specificity: 0.9295
# Epoch 16/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.1246 - accuracy: 0.9686 - specificity: 0.8989 - val_loss: 0.4705 - val_accuracy: 0.9281 - val_specificity: 0.9295
# Epoch 17/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.1259 - accuracy: 0.9663 - specificity: 0.8945 - val_loss: 0.3397 - val_accuracy: 0.9271 - val_specificity: 0.9266
# Epoch 18/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.1026 - accuracy: 0.9695 - specificity: 0.9043 - val_loss: 0.4132 - val_accuracy: 0.9344 - val_specificity: 0.9338
# Epoch 19/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.1147 - accuracy: 0.9752 - specificity: 0.9293 - val_loss: 0.4622 - val_accuracy: 0.9253 - val_specificity: 0.9248
# Epoch 20/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.1023 - accuracy: 0.9743 - specificity: 0.9143 - val_loss: 0.3681 - val_accuracy: 0.9499 - val_specificity: 0.9509
# Epoch 21/50
# 138/138 [==============================] - 1s 5ms/step - loss: 0.0982 - accuracy: 0.9731 - specificity: 0.9184 - val_loss: 0.3913 - val_accuracy: 0.9390 - val_specificity: 0.9402
# Epoch 22/50
# 138/138 [==============================] - 1s 5ms/step - loss: 0.1062 - accuracy: 0.9718 - specificity: 0.9270 - val_loss: 0.3783 - val_accuracy: 0.9463 - val_specificity: 0.9473
# Epoch 23/50
# 138/138 [==============================] - 1s 5ms/step - loss: 0.1044 - accuracy: 0.9745 - specificity: 0.9303 - val_loss: 0.3789 - val_accuracy: 0.9499 - val_specificity: 0.9509
# Epoch 24/50
# 138/138 [==============================] - 1s 5ms/step - loss: 0.0926 - accuracy: 0.9772 - specificity: 0.9356 - val_loss: 0.3436 - val_accuracy: 0.9536 - val_specificity: 0.9545
# Epoch 25/50
# 138/138 [==============================] - 1s 4ms/step - loss: 0.0882 - accuracy: 0.9811 - specificity: 0.9410 - val_loss: 0.3313 - val_accuracy: 0.9536 - val_specificity: 0.9545
# Epoch 26/50
# 138/138 [==============================] - 1s 5ms/step - loss: 0.0908 - accuracy: 0.9775 - specificity: 0.9367 - val_loss: 0.2858 - val_accuracy: 0.9636 - val_specificity: 0.9643
# Epoch 27/50
# 138/138 [==============================] - 1s 5ms/step - loss: 0.1291 - accuracy: 0.9756 - specificity: 0.9120 - val_loss: 0.6490 - val_accuracy: 0.9362 - val_specificity: 0.9355
# Epoch 28/50
# 138/138 [==============================] - 1s 5ms/step - loss: 0.1221 - accuracy: 0.9759 - specificity: 0.9157 - val_loss: 0.6073 - val_accuracy: 0.9362 - val_specificity: 0.9355
# Epoch 29/50
# 138/138 [==============================] - 1s 4ms/step - loss: 0.0934 - accuracy: 0.9793 - specificity: 0.9398 - val_loss: 0.4011 - val_accuracy: 0.9189 - val_specificity: 0.9186
# Epoch 30/50
# 138/138 [==============================] - 1s 4ms/step - loss: 0.1130 - accuracy: 0.9777 - specificity: 0.9170 - val_loss: 0.3627 - val_accuracy: 0.9517 - val_specificity: 0.9527
# Epoch 31/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0904 - accuracy: 0.9756 - specificity: 0.9152 - val_loss: 0.3380 - val_accuracy: 0.9636 - val_specificity: 0.9643
# Epoch 32/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0775 - accuracy: 0.9832 - specificity: 0.9675 - val_loss: 0.2947 - val_accuracy: 0.9545 - val_specificity: 0.9554
# Epoch 33/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0808 - accuracy: 0.9816 - specificity: 0.9504 - val_loss: 0.3233 - val_accuracy: 0.9481 - val_specificity: 0.9491
# Epoch 34/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0715 - accuracy: 0.9859 - specificity: 0.9546 - val_loss: 0.2678 - val_accuracy: 0.9663 - val_specificity: 0.9670
# Epoch 35/50
# 138/138 [==============================] - 1s 4ms/step - loss: 0.0590 - accuracy: 0.9850 - specificity: 0.9660 - val_loss: 0.3223 - val_accuracy: 0.9663 - val_specificity: 0.9670
# Epoch 36/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0680 - accuracy: 0.9882 - specificity: 0.9651 - val_loss: 0.2742 - val_accuracy: 0.9663 - val_specificity: 0.9670
# Epoch 37/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0918 - accuracy: 0.9768 - specificity: 0.9448 - val_loss: 0.2603 - val_accuracy: 0.9699 - val_specificity: 0.9705
# Epoch 38/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0755 - accuracy: 0.9793 - specificity: 0.9566 - val_loss: 0.2696 - val_accuracy: 0.9627 - val_specificity: 0.9634
# Epoch 39/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0699 - accuracy: 0.9836 - specificity: 0.9534 - val_loss: 0.2630 - val_accuracy: 0.9736 - val_specificity: 0.9741
# Epoch 40/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0693 - accuracy: 0.9863 - specificity: 0.9665 - val_loss: 0.3102 - val_accuracy: 0.9545 - val_specificity: 0.9554
# Epoch 41/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0700 - accuracy: 0.9845 - specificity: 0.9571 - val_loss: 0.2703 - val_accuracy: 0.9663 - val_specificity: 0.9670
# Epoch 42/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0608 - accuracy: 0.9872 - specificity: 0.9488 - val_loss: 0.2558 - val_accuracy: 0.9781 - val_specificity: 0.9786
# Epoch 43/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0568 - accuracy: 0.9870 - specificity: 0.9566 - val_loss: 0.2662 - val_accuracy: 0.9663 - val_specificity: 0.9670
# Epoch 44/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0573 - accuracy: 0.9879 - specificity: 0.9645 - val_loss: 0.2617 - val_accuracy: 0.9663 - val_specificity: 0.9670
# Epoch 45/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0610 - accuracy: 0.9879 - specificity: 0.9578 - val_loss: 0.3221 - val_accuracy: 0.9517 - val_specificity: 0.9527
# Epoch 46/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0572 - accuracy: 0.9882 - specificity: 0.9579 - val_loss: 0.2811 - val_accuracy: 0.9699 - val_specificity: 0.9705
# Epoch 47/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0590 - accuracy: 0.9895 - specificity: 0.9594 - val_loss: 0.2496 - val_accuracy: 0.9781 - val_specificity: 0.9786
# Epoch 48/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0513 - accuracy: 0.9888 - specificity: 0.9722 - val_loss: 0.2620 - val_accuracy: 0.9699 - val_specificity: 0.9705
# Epoch 49/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0624 - accuracy: 0.9904 - specificity: 0.9786 - val_loss: 0.2477 - val_accuracy: 0.9699 - val_specificity: 0.9705
# Epoch 50/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.1680 - accuracy: 0.9702 - specificity: 0.8705 - val_loss: 0.2384 - val_accuracy: 0.9818 - val_specificity: 0.9821

# %%
# Predecir en el conjunto de prueba
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# 31/31 [==============================] - 0s 2ms/step
# Precision: 99.34
# Especificidad: 90.48
# Exactitud: 96.88
# Sensibilidad: 97.31
# Error tipo I: 9.52
# Error tipo II: 2.69
