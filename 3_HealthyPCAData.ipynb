# %%
import pandas as pd
import numpy as np
import os

from sklearn import preprocessing
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import randint as sp_randint
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA
from sklearn.metrics import make_scorer
from sklearn.metrics import balanced_accuracy_score

from sklearn.model_selection import KFold
from sklearn.metrics import recall_score

# %% [markdown]
# ---
# ---
# Leemos datos

# %%
ruta = '/content/drive/MyDrive/TFM/TFM/Processed_Data/DataSetSinOutliers.csv'
dataset = pd.read_csv(ruta, sep="\t")

# %% [markdown]
# # Recalculo de columnas mediante PCA

# %%
# Normalizamos las características dentro del rango [0,1]
min_max_scaler = preprocessing.MinMaxScaler()

# Quitamos la columna de ID
columnas = dataset.columns.tolist()
columnas.remove(columnas[0])

features_norm = min_max_scaler.fit_transform(dataset[columnas])

dataset_norm = pd.DataFrame(features_norm, columns=columnas)

X = dataset_norm.drop(columns=['Health_state_disease'])  # Variables predictoras
y = dataset_norm['Health_state_disease']  # Variable objetivo

# Aplicamos PCA
pca = PCA(n_components=0.8)
features_pca = pca.fit_transform(X)
X = pd.DataFrame(features_pca)

# %%
#definimos funcion para mostrar los resultados
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix
# from sklearn.metrics import classification_report

LABELS = ["Healthy","Disease"]

def mostrar_resultados(y_test, pred_y):
    conf_matrix = confusion_matrix(y_test, pred_y)
    plt.figure(figsize=(9, 9))
    sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
    plt.title("Confusion matrix")
    plt.ylabel('True class')
    plt.xlabel('Predicted class')
    plt.show()

def medidas(cm):
  VP = cm[1][1]
  FP = cm[0][1]
  VN = cm[0][0]
  FN = cm[1][0]
  print("Precision:",round(VP/(VP+FP)*100,2))
  print("Especificidad:",round(VN/(VN+FP)*100,2))
  print("Exactitud:",round((VP+VN)/(VP+VN+FP+FN)*100,2))
  print("Sensibilidad:",round(VP/(VP+FN)*100,2))
  print("Error tipo I:",round(FP/(VN+FP)*100,2))
  print("Error tipo II:",round(FN/(VP+FN)*100,2))

# %% [markdown]
# # Random Over Sampler

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# Creamos con RandomOverSampler muestras de la clase minoritaria para contrarrestar el desbalanceo de clases
os =  RandomOverSampler(sampling_strategy=0.5)
X_train_res, y_train_res = os.fit_resample(X_train, y_train)

# %%
def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

# %% [markdown]
# # Regresión logística

# %%
# Inicializar y entrenar el modelo de regresión logística
model = LogisticRegression()
model.fit(X_train_res, y_train_res)

# Predecir en el conjunto de prueba
y_pred = model.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 99.55
# Especificidad: 93.65
# Exactitud: 95.97
# Sensibilidad: 96.12
# Error tipo I: 6.35
# Error tipo II: 3.88

# %% [markdown]
# ## Random Search

# %%
param_dist = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],  # Parámetro de regularización
    'penalty': ['l2', None],  # Tipo de penalización
    'solver': ['lbfgs', 'newton-cg', 'newton-cholesky', 'sag'],  # Algoritmo de optimización
    'class_weight': ['balanced', None] # Parámetro para ajustar los pesos de las clases
}

# %%
# Inicializar y entrenar el modelo de regresión logística
model = LogisticRegression()

# Realizar la búsqueda aleatoria de hiperparámetros
random_search = RandomizedSearchCV(estimator=model, param_distributions=param_dist, scoring=make_scorer(balanced_accuracy_score),
                                   n_iter=100, cv=5, random_state=42, n_jobs=-1)
random_search.fit(X_train_res, y_train_res)

# Obtener el mejor modelo
best_model = random_search.best_estimator_

# Predecir en el conjunto de prueba
y_pred = best_model.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:305: UserWarning: The total space of parameters 96 is smaller than n_iter=100. Running 96 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Precision: 98.59
# Especificidad: 79.37
# Exactitud: 96.57
# Sensibilidad: 97.74
# Error tipo I: 20.63
# Error tipo II: 2.26

# %%
report(random_search.cv_results_, n_top = 3)
# Out:
# Model with rank: 1
# Mean validation score: 0.985 (std: 0.002)
# Parameters: {'solver': 'lbfgs', 'penalty': None, 'class_weight': 'balanced', 'C': 0.001}
#
# Model with rank: 1
# Mean validation score: 0.985 (std: 0.002)
# Parameters: {'solver': 'lbfgs', 'penalty': None, 'class_weight': 'balanced', 'C': 0.01}
#
# Model with rank: 1
# Mean validation score: 0.985 (std: 0.002)
# Parameters: {'solver': 'lbfgs', 'penalty': None, 'class_weight': 'balanced', 'C': 0.1}
#
# Model with rank: 1
# Mean validation score: 0.985 (std: 0.002)
# Parameters: {'solver': 'lbfgs', 'penalty': None, 'class_weight': 'balanced', 'C': 1}
#
# Model with rank: 1
# Mean validation score: 0.985 (std: 0.002)
# Parameters: {'solver': 'lbfgs', 'penalty': None, 'class_weight': 'balanced', 'C': 10}
#
# Model with rank: 1
# Mean validation score: 0.985 (std: 0.002)
# Parameters: {'solver': 'lbfgs', 'penalty': None, 'class_weight': 'balanced', 'C': 100}

# %% [markdown]
# # Modelo KNN

# %%
# Inicializar el clasificador k-NN
knn = KNeighborsClassifier(n_neighbors=10, weights = 'distance')

# Entrenar el modelo
knn.fit(X_train_res, y_train_res)

# Realizar predicciones en el conjunto de prueba
y_pred = knn.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 99.77
# Especificidad: 96.83
# Exactitud: 92.54
# Sensibilidad: 92.25
# Error tipo I: 3.17
# Error tipo II: 7.75

# %% [markdown]
# ## Random Search

# %%
param_dist = {
    'n_neighbors': sp_randint(1, 20),  # Número de vecinos
    'weights': ['uniform', 'distance'],  # Método de asignación de pesos
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],  # Algoritmo para calcular los vecinos
    'leaf_size': sp_randint(10, 50),  # Tamaño de la hoja para algoritmos de árbol
    'p': [1, 2]  # Parámetro de potencia para la métrica Minkowski
}

# %%
# Inicializar el clasificador k-NN
knn = KNeighborsClassifier()

# Realizar la búsqueda aleatoria de hiperparámetros
random_search = RandomizedSearchCV(estimator=knn, param_distributions=param_dist, scoring=make_scorer(balanced_accuracy_score),
                                   n_iter=100, cv=5, random_state=42, n_jobs=-1)
random_search.fit(X_train_res, y_train_res)

# Obtener el mejor modelo
best_model = random_search.best_estimator_

# Realizar predicciones en el conjunto de prueba
y_pred = best_model.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 98.9
# Especificidad: 84.13
# Exactitud: 95.87
# Sensibilidad: 96.66
# Error tipo I: 15.87
# Error tipo II: 3.34

# %% [markdown]
# # Modelo Árbol de Decisión

# %%
# Inicializar el clasificador de árbol de decisión
dt_classifier = DecisionTreeClassifier(max_depth=10, random_state=42)

# Entrenar el modelo
dt_classifier.fit(X_train_res, y_train_res)

# Realizar predicciones en el conjunto de prueba
y_pred = dt_classifier.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 97.39
# Especificidad: 61.9
# Exactitud: 94.05
# Sensibilidad: 96.23
# Error tipo I: 38.1
# Error tipo II: 3.77

# %% [markdown]
# ## Random Search

# %%
param_dist = {
    'criterion': ['gini', 'entropy'],  # Criterio de calidad de la partición
    'splitter': ['best', 'random'],  # Estrategia para elegir la división en cada nodo
    'max_depth': [None] + list(sp_randint(1, 20).rvs(10)),  # Profundidad máxima del árbol
    'min_samples_split': sp_randint(2, 20),  # Número mínimo de muestras requeridas para dividir un nodo interno
    'min_samples_leaf': sp_randint(1, 20),  # Número mínimo de muestras requeridas para ser una hoja
    'max_features': ['auto', 'sqrt', 'log2', None],  # Número máximo de características a considerar en cada división
    'ccp_alpha': np.linspace(0.0, 0.5, 10)  # Parámetro de complejidad de coste mínimo
}

# %%
# Inicializar el clasificador de árbol de decisión
dt_classifier = DecisionTreeClassifier()

# Realizar la búsqueda aleatoria de hiperparámetros
random_search = RandomizedSearchCV(estimator=dt_classifier, param_distributions=param_dist, scoring=make_scorer(balanced_accuracy_score),
                                   n_iter=100, cv=5, random_state=42, n_jobs=-1)
random_search.fit(X_train_res, y_train_res)

# Obtener el mejor modelo
best_model = random_search.best_estimator_

# Realizar predicciones en el conjunto de prueba
y_pred = best_model.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 96.75
# Especificidad: 52.38
# Exactitud: 93.35
# Sensibilidad: 96.12
# Error tipo I: 47.62
# Error tipo II: 3.88

# %% [markdown]
# # Modelo Bosque Aleatorio

# %%
# Inicializar el clasificador de bosque aleatorio
rf_regressor  = RandomForestClassifier(max_depth=10, random_state=42)

# Entrenar el modelo
rf_regressor.fit(X_train_res, y_train_res)

# Realizar predicciones en el conjunto de prueba
y_pred = rf_regressor .predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 96.85
# Especificidad: 52.38
# Exactitud: 96.37
# Sensibilidad: 99.35
# Error tipo I: 47.62
# Error tipo II: 0.65

# %% [markdown]
# ## Random Search

# %%
param_dist = {"n_estimators": [8, 16, 32], # Número de árboles en el bosque aleatorio
              "max_features": ['auto', 'sqrt'], # Número de características a considerar en cada división
              "max_depth": [12, 8, 4], # Número máximo de niveles en el árbol
              "min_samples_split": sp_randint(2, 10), # Número mínimo de muestras requeridas para dividir un nodo
              "min_samples_leaf": sp_randint(1, 10), # Número mínimo de muestras requeridas en cada nodo hoja
              "bootstrap": [True, False], # Método de selección de muestras para entrenar cada árbol
              "criterion": ['log_loss', 'entropy', 'gini']} # Criterio de evaluación de la calidad de una división

# %%
classifier =  RandomForestClassifier()

# Realizar la búsqueda aleatoria de hiperparámetros
rnd_class = RandomizedSearchCV(estimator = classifier, param_distributions = param_dist,
                               n_iter = 100, cv = 5, random_state=0, n_jobs = -1,
                               scoring=make_scorer(balanced_accuracy_score))
rnd_class.fit(X_train_res, y_train_res)

# Inicializar el clasificador de bosque de árboles de decisión
classifier =  rnd_class.best_estimator_

# Realizar predicciones en el conjunto de prueba
y_pred = classifier.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 96.47
# Especificidad: 46.03
# Exactitud: 96.47
# Sensibilidad: 99.89
# Error tipo I: 53.97
# Error tipo II: 0.11

# %% [markdown]
# # Red neuronal

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Activation, Flatten
from tensorflow.keras.utils import plot_model
import keras.backend as K

# %%
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1 - y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

# %%
# Define la arquitectura de la red neuronal
model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),  # Capa oculta con activación ReLU
    Dropout(0.5),  # Dropout para regularización
    Dense(4, activation='relu'),  # capa oculta
    Dense(1, activation='relu')  # Capa de salida
])

# Compila el modelo
model.compile(optimizer='adam', loss='binary_crossentropy', metrics = ['accuracy', specificity])

# Entrena el modelo
model.fit(X_train_res, y_train_res, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 138/138 [==============================] - 2s 5ms/step - loss: 4.5240 - accuracy: 0.1751 - specificity: 0.9967 - val_loss: 0.2716 - val_accuracy: 1.0000 - val_specificity: 1.0000
# Epoch 2/50
# 138/138 [==============================] - 0s 3ms/step - loss: 1.0951 - accuracy: 0.4212 - specificity: 0.7296 - val_loss: 0.7431 - val_accuracy: 0.3015 - val_specificity: 0.3054
# Epoch 3/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.6345 - accuracy: 0.7261 - specificity: 0.3470 - val_loss: 0.9629 - val_accuracy: 0.1776 - val_specificity: 0.1820
# Epoch 4/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.5062 - accuracy: 0.8058 - specificity: 0.2968 - val_loss: 0.9290 - val_accuracy: 0.2432 - val_specificity: 0.2443
# Epoch 5/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.3920 - accuracy: 0.8595 - specificity: 0.3763 - val_loss: 0.9717 - val_accuracy: 0.3825 - val_specificity: 0.3809
# Epoch 6/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.3357 - accuracy: 0.8741 - specificity: 0.4155 - val_loss: 1.1196 - val_accuracy: 0.4217 - val_specificity: 0.4212
# Epoch 7/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.2792 - accuracy: 0.8916 - specificity: 0.4759 - val_loss: 1.0360 - val_accuracy: 0.5610 - val_specificity: 0.5598
# Epoch 8/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.2664 - accuracy: 0.9080 - specificity: 0.5747 - val_loss: 0.9411 - val_accuracy: 0.6530 - val_specificity: 0.6539
# Epoch 9/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.2387 - accuracy: 0.9119 - specificity: 0.6052 - val_loss: 0.9207 - val_accuracy: 0.6931 - val_specificity: 0.6932
# Epoch 10/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.2134 - accuracy: 0.9294 - specificity: 0.6734 - val_loss: 0.8803 - val_accuracy: 0.7259 - val_specificity: 0.7254
# Epoch 11/50
# 138/138 [==============================] - 1s 4ms/step - loss: 0.1982 - accuracy: 0.9344 - specificity: 0.7082 - val_loss: 0.8504 - val_accuracy: 0.7605 - val_specificity: 0.7612
# Epoch 12/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.1983 - accuracy: 0.9410 - specificity: 0.7814 - val_loss: 0.7858 - val_accuracy: 0.7996 - val_specificity: 0.7996
# Epoch 13/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.1816 - accuracy: 0.9440 - specificity: 0.7375 - val_loss: 0.7392 - val_accuracy: 0.8434 - val_specificity: 0.8425
# Epoch 14/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.1762 - accuracy: 0.9442 - specificity: 0.8050 - val_loss: 0.7735 - val_accuracy: 0.8179 - val_specificity: 0.8175
# Epoch 15/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.1867 - accuracy: 0.9469 - specificity: 0.7662 - val_loss: 0.7399 - val_accuracy: 0.8643 - val_specificity: 0.8650
# Epoch 16/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.1684 - accuracy: 0.9515 - specificity: 0.8046 - val_loss: 0.6805 - val_accuracy: 0.8889 - val_specificity: 0.8891
# Epoch 17/50
# 138/138 [==============================] - 1s 4ms/step - loss: 0.1691 - accuracy: 0.9542 - specificity: 0.8198 - val_loss: 0.6954 - val_accuracy: 0.8716 - val_specificity: 0.8721
# Epoch 18/50
# 138/138 [==============================] - 1s 5ms/step - loss: 0.1491 - accuracy: 0.9556 - specificity: 0.8219 - val_loss: 0.6711 - val_accuracy: 0.8816 - val_specificity: 0.8820
# Epoch 19/50
# 138/138 [==============================] - 1s 4ms/step - loss: 0.1381 - accuracy: 0.9608 - specificity: 0.8514 - val_loss: 0.6830 - val_accuracy: 0.8643 - val_specificity: 0.8650
# Epoch 20/50
# 138/138 [==============================] - 1s 5ms/step - loss: 0.1228 - accuracy: 0.9643 - specificity: 0.8241 - val_loss: 0.6274 - val_accuracy: 0.9126 - val_specificity: 0.9123
# Epoch 21/50
# 138/138 [==============================] - 1s 5ms/step - loss: 0.1312 - accuracy: 0.9602 - specificity: 0.8598 - val_loss: 0.6430 - val_accuracy: 0.8934 - val_specificity: 0.8936
# Epoch 22/50
# 138/138 [==============================] - 1s 5ms/step - loss: 0.1309 - accuracy: 0.9647 - specificity: 0.8450 - val_loss: 0.6142 - val_accuracy: 0.9089 - val_specificity: 0.9087
# Epoch 23/50
# 138/138 [==============================] - 1s 5ms/step - loss: 0.1227 - accuracy: 0.9654 - specificity: 0.8739 - val_loss: 0.5683 - val_accuracy: 0.9390 - val_specificity: 0.9382
# Epoch 24/50
# 138/138 [==============================] - 1s 6ms/step - loss: 0.1172 - accuracy: 0.9674 - specificity: 0.9014 - val_loss: 0.5758 - val_accuracy: 0.9353 - val_specificity: 0.9346
# Epoch 25/50
# 138/138 [==============================] - 1s 6ms/step - loss: 0.1215 - accuracy: 0.9656 - specificity: 0.8726 - val_loss: 0.5676 - val_accuracy: 0.9326 - val_specificity: 0.9320
# Epoch 26/50
# 138/138 [==============================] - 1s 4ms/step - loss: 0.1078 - accuracy: 0.9697 - specificity: 0.8922 - val_loss: 0.5667 - val_accuracy: 0.9335 - val_specificity: 0.9329
# Epoch 27/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.1097 - accuracy: 0.9677 - specificity: 0.8772 - val_loss: 0.5353 - val_accuracy: 0.9463 - val_specificity: 0.9454
# Epoch 28/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.1030 - accuracy: 0.9731 - specificity: 0.9098 - val_loss: 0.5421 - val_accuracy: 0.9290 - val_specificity: 0.9284
# Epoch 29/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.1022 - accuracy: 0.9743 - specificity: 0.9037 - val_loss: 0.5093 - val_accuracy: 0.9481 - val_specificity: 0.9471
# Epoch 30/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0912 - accuracy: 0.9722 - specificity: 0.8740 - val_loss: 0.5617 - val_accuracy: 0.9444 - val_specificity: 0.9436
# Epoch 31/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.1010 - accuracy: 0.9734 - specificity: 0.9000 - val_loss: 0.5262 - val_accuracy: 0.9490 - val_specificity: 0.9480
# Epoch 32/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.1005 - accuracy: 0.9775 - specificity: 0.9208 - val_loss: 0.4934 - val_accuracy: 0.9508 - val_specificity: 0.9498
# Epoch 33/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0900 - accuracy: 0.9738 - specificity: 0.8903 - val_loss: 0.4917 - val_accuracy: 0.9490 - val_specificity: 0.9480
# Epoch 34/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0891 - accuracy: 0.9747 - specificity: 0.9047 - val_loss: 0.5126 - val_accuracy: 0.9426 - val_specificity: 0.9418
# Epoch 35/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0822 - accuracy: 0.9781 - specificity: 0.9310 - val_loss: 0.4825 - val_accuracy: 0.9554 - val_specificity: 0.9543
# Epoch 36/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0948 - accuracy: 0.9793 - specificity: 0.9219 - val_loss: 0.5128 - val_accuracy: 0.9290 - val_specificity: 0.9284
# Epoch 37/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0911 - accuracy: 0.9759 - specificity: 0.9165 - val_loss: 0.5501 - val_accuracy: 0.9107 - val_specificity: 0.9105
# Epoch 38/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0871 - accuracy: 0.9775 - specificity: 0.9205 - val_loss: 0.4972 - val_accuracy: 0.9362 - val_specificity: 0.9355
# Epoch 39/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.1027 - accuracy: 0.9779 - specificity: 0.9233 - val_loss: 0.4454 - val_accuracy: 0.9572 - val_specificity: 0.9561
# Epoch 40/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0830 - accuracy: 0.9786 - specificity: 0.9481 - val_loss: 0.5100 - val_accuracy: 0.9317 - val_specificity: 0.9311
# Epoch 41/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0814 - accuracy: 0.9834 - specificity: 0.9499 - val_loss: 0.4615 - val_accuracy: 0.9572 - val_specificity: 0.9561
# Epoch 42/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0783 - accuracy: 0.9813 - specificity: 0.9450 - val_loss: 0.4728 - val_accuracy: 0.9508 - val_specificity: 0.9498
# Epoch 43/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0754 - accuracy: 0.9788 - specificity: 0.9257 - val_loss: 0.4083 - val_accuracy: 0.9718 - val_specificity: 0.9704
# Epoch 44/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.1021 - accuracy: 0.9763 - specificity: 0.9557 - val_loss: 0.5066 - val_accuracy: 0.9417 - val_specificity: 0.9409
# Epoch 45/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0769 - accuracy: 0.9761 - specificity: 0.9038 - val_loss: 0.4863 - val_accuracy: 0.9472 - val_specificity: 0.9463
# Epoch 46/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0766 - accuracy: 0.9793 - specificity: 0.9064 - val_loss: 0.4914 - val_accuracy: 0.9435 - val_specificity: 0.9427
# Epoch 47/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0711 - accuracy: 0.9834 - specificity: 0.9388 - val_loss: 0.5155 - val_accuracy: 0.9290 - val_specificity: 0.9284
# Epoch 48/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0675 - accuracy: 0.9820 - specificity: 0.9167 - val_loss: 0.4703 - val_accuracy: 0.9572 - val_specificity: 0.9561
# Epoch 49/50
# 138/138 [==============================] - 0s 3ms/step - loss: 0.0642 - accuracy: 0.9822 - specificity: 0.9343 - val_loss: 0.4425 - val_accuracy: 0.9581 - val_specificity: 0.9570
# Epoch 50/50
# 138/138 [==============================] - 1s 5ms/step - loss: 0.0679 - accuracy: 0.9841 - specificity: 0.9443 - val_loss: 0.4402 - val_accuracy: 0.9581 - val_specificity: 0.9570

# %%
# Predecir en el conjunto de prueba
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# 31/31 [==============================] - 0s 1ms/step
# Precision: 98.92
# Especificidad: 84.13
# Exactitud: 97.68
# Sensibilidad: 98.6
# Error tipo I: 15.87
# Error tipo II: 1.4
