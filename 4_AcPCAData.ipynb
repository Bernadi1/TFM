# %%
import pandas as pd
import numpy as np
import os

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import randint as sp_randint
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA
from sklearn.metrics import make_scorer
from sklearn.metrics import balanced_accuracy_score

from sklearn.model_selection import KFold
from sklearn.metrics import recall_score

# %% [markdown]
# ---
# ---
# Leemos datos

# %%
ruta = '/content/drive/MyDrive/TFM/TFM/Processed_Data/DataSetAdenocarcinomaSinOutliers.csv'
dataset = pd.read_csv(ruta, sep="\t")

# %% [markdown]
# # Recalculo de columnas mediante PCA

# %%
# Normalizamos las características dentro del rango [0,1]
min_max_scaler = preprocessing.MinMaxScaler()

# Quitamos la columna de ID
columnas = dataset.columns.tolist()
columnas.remove(columnas[0])

features_norm = min_max_scaler.fit_transform(dataset[columnas])

dataset_norm = pd.DataFrame(features_norm, columns=columnas)

X = dataset_norm.drop(columns=['Adenocarcinoma'])  # Variables predictoras
y = dataset_norm['Adenocarcinoma']  # Variable objetivo

# Aplicamos PCA
pca = PCA(n_components=0.8)
features_pca = pca.fit_transform(X)
X = pd.DataFrame(features_pca)

# %%
#definimos funcion para mostrar los resultados
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix

LABELS = ["Healthy","Disease"]

def mostrar_resultados(y_test, pred_y):
    conf_matrix = confusion_matrix(y_test, pred_y)
    plt.figure(figsize=(9, 9))
    sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
    plt.title("Confusion matrix")
    plt.ylabel('True class')
    plt.xlabel('Predicted class')
    plt.show()

def medidas(cm):
  VP = cm[1][1]
  FP = cm[0][1]
  VN = cm[0][0]
  FN = cm[1][0]
  print("Precision:",round(VP/(VP+FP)*100,2))
  print("Especificidad:",round(VN/(VN+FP)*100,2))
  print("Exactitud:",round((VP+VN)/(VP+VN+FP+FN)*100,2))
  print("Sensibilidad:",round(VP/(VP+FN)*100,2))
  print("Error tipo I:",round(FP/(VN+FP)*100,2))
  print("Error tipo II:",round(FN/(VP+FN)*100,2))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# %%
def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

# %% [markdown]
# # Regresión logística

# %%
# Inicializar y entrenar el modelo de regresión logística
model = LogisticRegression()
model.fit(X_train, y_train)

# Predecir en el conjunto de prueba
y_pred = model.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 86.72
# Especificidad: 88.64
# Exactitud: 89.62
# Sensibilidad: 90.81
# Error tipo I: 11.36
# Error tipo II: 9.19

# %% [markdown]
# ## Random Search

# %%
param_dist = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],  # Parámetro de regularización
    'penalty': ['l2', None],  # Tipo de penalización
    'solver': ['lbfgs', 'newton-cg', 'newton-cholesky', 'sag'],  # Algoritmo de optimización
    'class_weight': ['balanced', None] # Parámetro para ajustar los pesos de las clases
}

# %%
# Inicializar y entrenar el modelo de regresión logística
model = LogisticRegression()

# Realizar la búsqueda aleatoria de hiperparámetros
random_search = RandomizedSearchCV(estimator=model, param_distributions=param_dist, scoring=make_scorer(balanced_accuracy_score),
                                   n_iter=100, cv=5, random_state=42, n_jobs=-1)
random_search.fit(X_train, y_train)

# Obtener el mejor modelo
best_model = random_search.best_estimator_

# Predecir en el conjunto de prueba
y_pred = best_model.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:305: UserWarning: The total space of parameters 96 is smaller than n_iter=100. Running 96 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Precision: 84.65
# Especificidad: 86.08
# Exactitud: 89.62
# Sensibilidad: 93.95
# Error tipo I: 13.92
# Error tipo II: 6.05

# %%
report(random_search.cv_results_, n_top = 3)
# Out:
# Model with rank: 1
# Mean validation score: 0.882 (std: 0.006)
# Parameters: {'solver': 'lbfgs', 'penalty': 'l2', 'class_weight': 'balanced', 'C': 1}
#
# Model with rank: 1
# Mean validation score: 0.882 (std: 0.006)
# Parameters: {'solver': 'newton-cg', 'penalty': 'l2', 'class_weight': 'balanced', 'C': 1}
#
# Model with rank: 1
# Mean validation score: 0.882 (std: 0.006)
# Parameters: {'solver': 'newton-cholesky', 'penalty': 'l2', 'class_weight': 'balanced', 'C': 1}
#
# Model with rank: 1
# Mean validation score: 0.882 (std: 0.006)
# Parameters: {'solver': 'sag', 'penalty': 'l2', 'class_weight': 'balanced', 'C': 1}

# %% [markdown]
# # Modelo KNN

# %%
# Inicializar el clasificador k-NN
knn = KNeighborsClassifier(n_neighbors=10, weights = 'distance')

# Entrenar el modelo
knn.fit(X_train, y_train)

# Realizar predicciones en el conjunto de prueba
y_pred = knn.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 87.02
# Especificidad: 89.38
# Exactitud: 88.41
# Sensibilidad: 87.22
# Error tipo I: 10.62
# Error tipo II: 12.78

# %% [markdown]
# ## Random Search

# %%
param_dist = {
    'n_neighbors': sp_randint(1, 20),  # Número de vecinos
    'weights': ['uniform', 'distance'],  # Método de asignación de pesos
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],  # Algoritmo para calcular los vecinos
    'leaf_size': sp_randint(10, 50),  # Tamaño de la hoja para algoritmos de árbol
    'p': [1, 2]  # Parámetro de potencia para la métrica Minkowski
}

# %%
# Inicializar el clasificador k-NN
knn = KNeighborsClassifier()

# Realizar la búsqueda aleatoria de hiperparámetros
random_search = RandomizedSearchCV(estimator=knn, param_distributions=param_dist, scoring=make_scorer(balanced_accuracy_score),
                                   n_iter=100, cv=5, random_state=42, n_jobs=-1)
random_search.fit(X_train, y_train)

# Obtener el mejor modelo
best_model = random_search.best_estimator_

# Realizar predicciones en el conjunto de prueba
y_pred = best_model.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 87.02
# Especificidad: 89.38
# Exactitud: 88.41
# Sensibilidad: 87.22
# Error tipo I: 10.62
# Error tipo II: 12.78

# %% [markdown]
# # Modelo Árbol de Decisión

# %%
# Inicializar el clasificador de árbol de decisión
dt_classifier = DecisionTreeClassifier(max_depth=10, random_state=42)

# Entrenar el modelo
dt_classifier.fit(X_train, y_train)

# Realizar predicciones en el conjunto de prueba
y_pred = dt_classifier.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 77.51
# Especificidad: 81.14
# Exactitud: 80.44
# Sensibilidad: 79.6
# Error tipo I: 18.86
# Error tipo II: 20.4

# %% [markdown]
# ## Random Search

# %%
param_dist = {
    'criterion': ['gini', 'entropy'],  # Criterio de calidad de la partición
    'splitter': ['best', 'random'],  # Estrategia para elegir la división en cada nodo
    'max_depth': [None] + list(sp_randint(1, 20).rvs(10)),  # Profundidad máxima del árbol
    'min_samples_split': sp_randint(2, 20),  # Número mínimo de muestras requeridas para dividir un nodo interno
    'min_samples_leaf': sp_randint(1, 20),  # Número mínimo de muestras requeridas para ser una hoja
    'max_features': ['auto', 'sqrt', 'log2', None],  # Número máximo de características a considerar en cada división
    'ccp_alpha': np.linspace(0.0, 0.5, 10)  # Parámetro de complejidad de coste mínimo
}

# %%
# Inicializar el clasificador de árbol de decisión
dt_classifier = DecisionTreeClassifier()

# Realizar la búsqueda aleatoria de hiperparámetros
random_search = RandomizedSearchCV(estimator=dt_classifier, param_distributions=param_dist, scoring=make_scorer(balanced_accuracy_score),
                                   n_iter=100, cv=5, random_state=42, n_jobs=-1)
random_search.fit(X_train, y_train)

# Obtener el mejor modelo
best_model = random_search.best_estimator_

# Realizar predicciones en el conjunto de prueba
y_pred = best_model.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 80.93
# Especificidad: 84.98
# Exactitud: 81.85
# Sensibilidad: 78.03
# Error tipo I: 15.02
# Error tipo II: 21.97

# %% [markdown]
# # Modelo Bosque Aleatorio

# %%
# Inicializar el clasificador de bosque aleatorio
rf_regressor  = RandomForestClassifier(max_depth=10, random_state=42)

# Entrenar el modelo
rf_regressor.fit(X_train, y_train)

# Realizar predicciones en el conjunto de prueba
y_pred = rf_regressor .predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# Precision: 87.77
# Especificidad: 90.66
# Exactitud: 86.79
# Sensibilidad: 82.06
# Error tipo I: 9.34
# Error tipo II: 17.94

# %% [markdown]
# ## Random Search

# %%
param_dist = {"n_estimators": [8, 16, 32], # Número de árboles en el bosque aleatorio
              "max_features": ['auto', 'sqrt'], # Número de características a considerar en cada división
              "max_depth": [12, 8, 4], # Número máximo de niveles en el árbol
              "min_samples_split": sp_randint(2, 10), # Número mínimo de muestras requeridas para dividir un nodo
              "min_samples_leaf": sp_randint(1, 10), # Número mínimo de muestras requeridas en cada nodo hoja
              "bootstrap": [True, False], # Método de selección de muestras para entrenar cada árbol
              "criterion": ['log_loss', 'entropy', 'gini']} # Criterio de evaluación de la calidad de una división

# %%
classifier =  RandomForestClassifier()

# Realizar la búsqueda aleatoria de hiperparámetros
rnd_class = RandomizedSearchCV(estimator = classifier, param_distributions = param_dist,
                               n_iter = 100, cv = 5, random_state=42, n_jobs = -1,
                               scoring=make_scorer(balanced_accuracy_score))
rnd_class.fit(X_train, y_train)

# Inicializar el clasificador de bosque de árboles de decisión
classifier =  rnd_class.best_estimator_

# Realizar predicciones en el conjunto de prueba
y_pred = classifier.predict(X_test)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Precision: 88.62
# Especificidad: 91.39
# Exactitud: 87.2
# Sensibilidad: 82.06
# Error tipo I: 8.61
# Error tipo II: 17.94

# %% [markdown]
# # Red neuronal

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Activation, Flatten
from tensorflow.keras.utils import plot_model
import keras.backend as K

# %%
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1 - y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

# %%
# Define la arquitectura de la red neuronal
model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),  # Capa oculta con activación ReLU
    Dropout(0.5),  # Dropout para regularización
    Dense(8, activation='relu'),  # capa oculta
    Dense(1, activation='relu')  # Capa de salida
])

# Compila el modelo
model.compile(optimizer='adam', loss='binary_crossentropy', metrics = ['accuracy', specificity])

# Entrena el modelo
model.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 2s 5ms/step - loss: 1.3345 - accuracy: 0.5813 - specificity: 0.9734 - val_loss: 0.6604 - val_accuracy: 0.5844 - val_specificity: 0.9943
# Epoch 2/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6338 - accuracy: 0.6396 - specificity: 0.9186 - val_loss: 0.5136 - val_accuracy: 0.7103 - val_specificity: 0.9397
# Epoch 3/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5294 - accuracy: 0.7353 - specificity: 0.8830 - val_loss: 0.4379 - val_accuracy: 0.7997 - val_specificity: 0.9256
# Epoch 4/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4594 - accuracy: 0.7807 - specificity: 0.8825 - val_loss: 0.4170 - val_accuracy: 0.8350 - val_specificity: 0.9117
# Epoch 5/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4148 - accuracy: 0.8125 - specificity: 0.8858 - val_loss: 0.4097 - val_accuracy: 0.8602 - val_specificity: 0.8620
# Epoch 6/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4227 - accuracy: 0.8283 - specificity: 0.8860 - val_loss: 0.3840 - val_accuracy: 0.8463 - val_specificity: 0.8928
# Epoch 7/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3908 - accuracy: 0.8349 - specificity: 0.9032 - val_loss: 0.3706 - val_accuracy: 0.8577 - val_specificity: 0.8990
# Epoch 8/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3714 - accuracy: 0.8406 - specificity: 0.9031 - val_loss: 0.3803 - val_accuracy: 0.8577 - val_specificity: 0.9064
# Epoch 9/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3425 - accuracy: 0.8604 - specificity: 0.8992 - val_loss: 0.4104 - val_accuracy: 0.8350 - val_specificity: 0.9379
# Epoch 10/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3623 - accuracy: 0.8311 - specificity: 0.9260 - val_loss: 0.3998 - val_accuracy: 0.8426 - val_specificity: 0.9200
# Epoch 11/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3306 - accuracy: 0.8579 - specificity: 0.9144 - val_loss: 0.3909 - val_accuracy: 0.8564 - val_specificity: 0.8964
# Epoch 12/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3560 - accuracy: 0.8607 - specificity: 0.9294 - val_loss: 0.4188 - val_accuracy: 0.8287 - val_specificity: 0.9304
# Epoch 13/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3417 - accuracy: 0.8503 - specificity: 0.9263 - val_loss: 0.4687 - val_accuracy: 0.8678 - val_specificity: 0.9042
# Epoch 14/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3350 - accuracy: 0.8696 - specificity: 0.9000 - val_loss: 0.4354 - val_accuracy: 0.8703 - val_specificity: 0.9020
# Epoch 15/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3337 - accuracy: 0.8614 - specificity: 0.9223 - val_loss: 0.4344 - val_accuracy: 0.8615 - val_specificity: 0.9095
# Epoch 16/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3124 - accuracy: 0.8639 - specificity: 0.9150 - val_loss: 0.4165 - val_accuracy: 0.8526 - val_specificity: 0.9036
# Epoch 17/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3015 - accuracy: 0.8727 - specificity: 0.9217 - val_loss: 0.4431 - val_accuracy: 0.8615 - val_specificity: 0.8911
# Epoch 18/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2775 - accuracy: 0.8746 - specificity: 0.9141 - val_loss: 0.4088 - val_accuracy: 0.8501 - val_specificity: 0.9110
# Epoch 19/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3001 - accuracy: 0.8743 - specificity: 0.9299 - val_loss: 0.4447 - val_accuracy: 0.8501 - val_specificity: 0.9033
# Epoch 20/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3145 - accuracy: 0.8447 - specificity: 0.9541 - val_loss: 0.4522 - val_accuracy: 0.8237 - val_specificity: 0.9230
# Epoch 21/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3045 - accuracy: 0.8604 - specificity: 0.9383 - val_loss: 0.4382 - val_accuracy: 0.8363 - val_specificity: 0.9055
# Epoch 22/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2806 - accuracy: 0.8730 - specificity: 0.9373 - val_loss: 0.4381 - val_accuracy: 0.8476 - val_specificity: 0.9062
# Epoch 23/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2957 - accuracy: 0.8746 - specificity: 0.9210 - val_loss: 0.4373 - val_accuracy: 0.8539 - val_specificity: 0.9062
# Epoch 24/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2842 - accuracy: 0.8891 - specificity: 0.9341 - val_loss: 0.4322 - val_accuracy: 0.8526 - val_specificity: 0.9182
# Epoch 25/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2832 - accuracy: 0.8806 - specificity: 0.9260 - val_loss: 0.4165 - val_accuracy: 0.8640 - val_specificity: 0.9077
# Epoch 26/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2582 - accuracy: 0.8891 - specificity: 0.9285 - val_loss: 0.4303 - val_accuracy: 0.8627 - val_specificity: 0.9052
# Epoch 27/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3000 - accuracy: 0.8929 - specificity: 0.9320 - val_loss: 0.4286 - val_accuracy: 0.8552 - val_specificity: 0.9161
# Epoch 28/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2825 - accuracy: 0.8822 - specificity: 0.9342 - val_loss: 0.4596 - val_accuracy: 0.8526 - val_specificity: 0.9150
# Epoch 29/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2608 - accuracy: 0.8926 - specificity: 0.9318 - val_loss: 0.4741 - val_accuracy: 0.8715 - val_specificity: 0.9021
# Epoch 30/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2651 - accuracy: 0.8992 - specificity: 0.9234 - val_loss: 0.4737 - val_accuracy: 0.8728 - val_specificity: 0.9004
# Epoch 31/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2318 - accuracy: 0.9121 - specificity: 0.9292 - val_loss: 0.5138 - val_accuracy: 0.8741 - val_specificity: 0.9044
# Epoch 32/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2435 - accuracy: 0.9118 - specificity: 0.9331 - val_loss: 0.5025 - val_accuracy: 0.8766 - val_specificity: 0.9053
# Epoch 33/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2309 - accuracy: 0.9112 - specificity: 0.9341 - val_loss: 0.5008 - val_accuracy: 0.8741 - val_specificity: 0.9071
# Epoch 34/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2356 - accuracy: 0.9159 - specificity: 0.9333 - val_loss: 0.5326 - val_accuracy: 0.8804 - val_specificity: 0.9113
# Epoch 35/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2336 - accuracy: 0.9140 - specificity: 0.9247 - val_loss: 0.5266 - val_accuracy: 0.8778 - val_specificity: 0.9014
# Epoch 36/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2229 - accuracy: 0.9108 - specificity: 0.9325 - val_loss: 0.5191 - val_accuracy: 0.8690 - val_specificity: 0.9067
# Epoch 37/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2230 - accuracy: 0.9168 - specificity: 0.9279 - val_loss: 0.5309 - val_accuracy: 0.8715 - val_specificity: 0.9046
# Epoch 38/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2169 - accuracy: 0.9108 - specificity: 0.9487 - val_loss: 0.5425 - val_accuracy: 0.8615 - val_specificity: 0.9097
# Epoch 39/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2078 - accuracy: 0.9209 - specificity: 0.9375 - val_loss: 0.5439 - val_accuracy: 0.8766 - val_specificity: 0.8964
# Epoch 40/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2372 - accuracy: 0.9263 - specificity: 0.9274 - val_loss: 0.5388 - val_accuracy: 0.8791 - val_specificity: 0.8914
# Epoch 41/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2222 - accuracy: 0.9279 - specificity: 0.9230 - val_loss: 0.5554 - val_accuracy: 0.8816 - val_specificity: 0.8855
# Epoch 42/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2189 - accuracy: 0.9269 - specificity: 0.9286 - val_loss: 0.6025 - val_accuracy: 0.8766 - val_specificity: 0.8966
# Epoch 43/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2018 - accuracy: 0.9323 - specificity: 0.9333 - val_loss: 0.6015 - val_accuracy: 0.8816 - val_specificity: 0.8941
# Epoch 44/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1830 - accuracy: 0.9370 - specificity: 0.9374 - val_loss: 0.6054 - val_accuracy: 0.8766 - val_specificity: 0.9025
# Epoch 45/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2110 - accuracy: 0.9354 - specificity: 0.9403 - val_loss: 0.6430 - val_accuracy: 0.8778 - val_specificity: 0.9134
# Epoch 46/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1831 - accuracy: 0.9370 - specificity: 0.9363 - val_loss: 0.6458 - val_accuracy: 0.8804 - val_specificity: 0.8808
# Epoch 47/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1988 - accuracy: 0.9304 - specificity: 0.9309 - val_loss: 0.6484 - val_accuracy: 0.8766 - val_specificity: 0.8904
# Epoch 48/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2023 - accuracy: 0.9405 - specificity: 0.9337 - val_loss: 0.6633 - val_accuracy: 0.8804 - val_specificity: 0.8906
# Epoch 49/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1925 - accuracy: 0.9382 - specificity: 0.9301 - val_loss: 0.6518 - val_accuracy: 0.8791 - val_specificity: 0.8926
# Epoch 50/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1811 - accuracy: 0.9401 - specificity: 0.9369 - val_loss: 0.6657 - val_accuracy: 0.8728 - val_specificity: 0.9135

# %%
# Evaluar el modelo en el conjunto de prueba (si tienes uno)
# Predecir en el conjunto de prueba
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)

# Calcular la precisión del modelo
mostrar_resultados(y_test, y_pred)

# Mostrar medidas
cm = confusion_matrix(y_test, y_pred)
medidas(cm)
# Out:
# 31/31 [==============================] - 0s 2ms/step
# Precision: 89.18
# Especificidad: 91.58
# Exactitud: 88.61
# Sensibilidad: 84.98
# Error tipo I: 8.42
# Error tipo II: 15.02
